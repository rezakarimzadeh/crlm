# %%
import json
import pandas as pd

def jsons_to_df(json_paths, method_names, columns=None):
    rows = []
    
    for path, name in zip(json_paths, method_names):
        with open(path, "r") as f:
            d = json.load(f)
        d["method"] = name
        rows.append(d)
    
    df = pd.DataFrame(rows)
    
    if columns:
        df = df[["method"] + columns]
    
    display(df)
    # return df

columns = ['roc_auc_mean', 'roc_auc_std', 'accuracy_mean', 'accuracy_std']

# %%
json_paths = [
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/RadiomicsMIL/overall_survival_24m/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/StatisticalPoolingMLP/overall_survival_24m/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/GooglenetLSTM/overall_survival_24m/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/RPNet3D/overall_survival_24m/fivefold_aggregated_results.json"
    ]
method_names = ['RadiomicsMIL', 'StatisticalPoolingMLP', 'GooglenetLSTM', 'RPNet3D']
print("overall survival results:")
jsons_to_df(json_paths, method_names, columns)
# Out:
# overall survival results:
#                   method  roc_auc_mean  roc_auc_std  accuracy_mean  \
# 0           RadiomicsMIL      0.683450     0.063191       0.669304
# 1  StatisticalPoolingMLP      0.643699     0.070298       0.652140
# 2          GooglenetLSTM      0.612315     0.064886       0.599371
# 3                RPNet3D      0.618470     0.079630       0.559496
#
#    accuracy_std
# 0      0.029990
# 1      0.043375
# 2      0.053629
# 3      0.067616

# %%
json_paths = [
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/RadiomicsMIL/early_recurrence/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/StatisticalPoolingMLP/early_recurrence/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/GooglenetLSTM/early_recurrence/fivefold_aggregated_results.json",
    ]
method_names = ['RadiomicsMIL', 'StatisticalPoolingMLP', 'GooglenetLSTM']
print("early recurrence results:")
jsons_to_df(json_paths, method_names, columns)
# Out:
# early recurrence results:
#                   method  roc_auc_mean  roc_auc_std  accuracy_mean  \
# 0           RadiomicsMIL      0.597661     0.030363       0.510906
# 1  StatisticalPoolingMLP      0.648638     0.058590       0.594107
# 2          GooglenetLSTM      0.586581     0.038871       0.575901
#
#    accuracy_std
# 0      0.073076
# 1      0.080775
# 2      0.056455

# %%
json_paths = [
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/RadiomicsMIL/morph_response/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/StatisticalPoolingMLP/morph_response/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/GooglenetLSTM/morph_response/fivefold_aggregated_results.json",
    ]
method_names = ['RadiomicsMIL', 'StatisticalPoolingMLP', 'GooglenetLSTM']
print("morphology response results (3 classes):")
jsons_to_df(json_paths, method_names, columns)
# Out:
# morphology response results (3 classes):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 8
#       6 method_names = ['RadiomicsMIL', 'StatisticalPoolingMLP', 'GooglenetLSTM']
#       7 print("morphology response results (3 classes):")
# ----> 8 jsons_to_df(json_paths, method_names, columns)
#
# Cell In[25], line 8, in jsons_to_df(json_paths, method_names, columns)
#       5 rows = []
#       7 for path, name in zip(json_paths, method_names):
# ----> 8     with open(path, "r") as f:
#       9         d = json.load(f)
#      10     d["method"] = name
#
# File ~/miniconda3/envs/py310_crlm/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
# ...

# %%
json_paths = [
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/RadiomicsMIL/pathology/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/StatisticalPoolingMLP/pathology/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/GooglenetLSTM/pathology/fivefold_aggregated_results.json",
    
    ]
method_names = ['RadiomicsMIL', 'StatisticalPoolingMLP', 'GooglenetLSTM']
print("pathologye results:")
jsons_to_df(json_paths, method_names, columns)
# Out:
# pathologye results:
#                   method  roc_auc_mean  roc_auc_std  accuracy_mean  \
# 0           RadiomicsMIL      0.522525     0.040022       0.560530
# 1  StatisticalPoolingMLP      0.552915     0.098536       0.569109
# 2          GooglenetLSTM      0.510597     0.075070       0.506651
#
#    accuracy_std
# 0      0.028296
# 1      0.064655
# 2      0.062242

# %%
json_paths = [
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/MorphScoreRadiomicsMIL/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/MorphScoreStatisticalPoolingMLP/shape_boundary_intensity_texture/fivefold_aggregated_results.json",
    "/mnt/l/Basic/divi/jstoker/slicer_pdac/Marius/Reza Morphology/codes/Results/MorphScoreGooglenetLSTM/fivefold_aggregated_results.json",
    ]
method_names = ['MorphScoreRadiomicsMIL', 'MorphScoreStatisticalPoolingMLP', 'MorphScoreGooglenetLSTM']
print("morphology score results (3 classes):")
jsons_to_df(json_paths, method_names, columns)
# Out:
# morphology score results (3 classes):
#                             method  roc_auc_mean  roc_auc_std  accuracy_mean  \
# 0           MorphScoreRadiomicsMIL      0.528555     0.037069       0.271744
# 1  MorphScoreStatisticalPoolingMLP      0.528456     0.034668       0.399380
# 2          MorphScoreGooglenetLSTM      0.541086     0.044038       0.364477
#
#    accuracy_std
# 0      0.119958
# 1      0.073733
# 2      0.072910
