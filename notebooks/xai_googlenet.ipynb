# %%
from models.googlenet_lstm import MorphScoreGooglenetLSTM
from dataloaders.googlenet_dataloader import get_cnn_dataloaders
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from models.googlenet_lstm import MorphScoreGooglenetLSTM
#       2 from dataloaders.googlenet_dataloader import get_cnn_dataloaders
#
# ModuleNotFoundError: No module named 'models'
